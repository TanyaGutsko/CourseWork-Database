# %%
#ВЫВОД ВСЕХ СТУДЕНТОВ И СКОЛЬКО ИЗ КАЖДОЙ ГРУППЫ
import json

with open('E:/course work/CTF MF.2022-02-10/db/users.json') as file:
    f = file.read()
    data = json.loads(f)

for text in data['results']:
    if text['affiliation'] is not None:
        print(f"Имя: {text['name']}, email: {text['email']}, группа: {text['affiliation']}")
    else:
        print(f"Имя: {text['name']}, email: {text['email']}, группа: не указана")

#Тут начинает считать, сколько из каждой группы
counts = dict()
for text in data['results']:
    if text['affiliation'] in counts.keys():
        counts[text['affiliation']] += 1
    else:
        counts[text['affiliation']] = 1

print("\nКоличество студентов в системе из каждой группы: ")
for key, value in counts.items():
    if key is not None:
        print(f"Группа \"{key}\" - {value} человек в системе")
    else:
        print(f"У {value} человек в системе группа не указана")
# Out:
# Имя: admin, email: admin@admin.com, группа: не указана
# Имя: dirvuk, email: dirvuk@gmail.com, группа: не указана
# Имя: Urbanovich_AI, email: urbanovichwork@gmail.com, группа: не указана
# Имя: kadan, email: kadan@mf.grsu.by, группа: не указана
# Имя: testuser, email: small@mf.grsu.by, группа: не указана
# Имя: ctfeditor, email: ctf@mf.grsu.by, группа: не указана
# Имя: ethnia, email: taranko.ev@mf.grsu.by, группа: не указана
# Имя: Palina Platava, email: platova_po_16@mf.grsu.by, группа: не указана
# Имя: Vladimir Shilko, email: shilko02@inbox.ru, группа: не указана
# Имя: Maximilin, email: ynulevich_mv_20@mf.grsu.by, группа: не указана
# Имя: nimon, email: kozlyk_te_20@mf.grsu.by, группа: не указана
# Имя: Каревский Арсентий, email: karevskij_aa_20@mf.grsu.by, группа: КБ-201
# Имя: Куликов Дмитрий, email: kulikov_da_20@mf.grsu.by, группа: КБ-201
# Имя: Лелевич Алексей, email: lelevich_ag_20@mf.grsu.by, группа: КБ-201
# Имя: Alice, email: alica.lancraft@gmail.com, группа: не указана
# Имя: Maks, email: karpeychik.maks@mail.ru, группа: не указана
# Имя: Kedel Yuliya, email: kedel_ja_19@mf.grsu.by, группа: не указана
# Имя: Victoria, email: podstavskay_vd_19@mf.grsu.by, группа: не указана
# Имя: IvanMur, email: mureny_iv_19@mf.grsu.by, группа: не указана
# Имя: Nastya, email: rust_aa_19@mf.grsu.by, группа: не указана
# Имя: Alexander, email: kuryn_aj_19@mf.grsu.by, группа: не указана
# Имя: Taras, email: tarasova_na_19@mf.grsu.by, группа: не указана
# Имя: Vika, email: sljsareva_vr_19@mf.grsu.by, группа: не указана
# Имя: Даниил Логин, email: logindaniil333@gmail.com, группа: не указана
# Имя: Zazar, email: kartashevich_zl_19@mf.grsu.by, группа: не указана
# Имя: Юрий, email: krupich_jm_19@mf.grsu.by, группа: не указана
# Имя: Maxanko Maxim, email: maxanko_mv_20@mf.grsu.by, группа: не указана
# Имя: Новиков Родион, email: rodion.novikov.2002@mail.ru, группа: КБ-201
# Имя: Валера, email: cidikvalera@gmail.com, группа: не указана
# Имя: Клеменя Алеся, email: klemeny_ap_20@mf.grsu.by, группа: КБ-201
# Имя: Санько Дмитрий, email: sanko_ds_20@mf.grsu.by, группа: КБ-201
# Имя: Tatiana, email: tatushonok@mail.ru, группа: не указана
# Имя: Скоробогатов Иван, email: skorobogatov_is_20@cs.mf.grsu.by, группа: КБ-201
# Имя: Evgen Fizik, email: woishnis@mail.ru, группа: не указана
# Имя: OMG, email: zolga20@gmail.com, группа: не указана
# Имя: Matvey, email: matvej.yakovenko@gmail.com, группа: не указана
# Имя: viktoria, email: vikkovalchuk25@email.com, группа: не указана
# Имя: Maksimovich Denis, email: dm2094068@gmail.com, группа: не указана
# Имя: Arina, email: yamabukisayo@gmail.com, группа: не указана
# Имя: polina, email: basalaypolina2007@gmail.com, группа: не указана
# Имя: ksenia, email: kseniaanuskevic510@gmail.com, группа: не указана
# Имя: Lera, email: dingilevskaalera@gmail.com, группа: не указана
# Имя: Дарья Катанекша, email: dkataneksha00@mail.ru, группа: не указана
# Имя: VitalyaArmatura, email: master7793@gmail.com, группа: не указана
# Имя: ViacheslavCyberMan, email: leogiss04@mail.ru, группа: не указана
# Имя: OLEG-KIBORG, email: oleshkahotyanovich@mail.ru, группа: не указана
# Имя: Tuzenciy, email: andrej@matujzo.of.by, группа: Вороновская Средняя Школа
# Имя: Daria Markel, email: daskamarkel@gmail.com, группа: не указана
# Имя: Ovest, email: cladcladclad@mail.ru, группа: не указана
# Имя: дмитрий кухта, email: kuhta26@mail.ru, группа: не указана
# Имя: anonim, email: adriansatalin@gmail.com, группа: не указана
# Имя: igorrunin, email: igorrunin222@mail.ru, группа: не указана
# Имя: EVG, email: evgenvoishnis@gmail.com, группа: не указана
# Имя: OnlyBlack#1992, email: steamng228@gmail.com, группа: не указана
# Имя: собака, email: grhziwxhvs@gmail.com, группа: не указана
# Имя: daan, email: olgak5176@gmail.com, группа: не указана
# Имя: читос с сыром, email: lukashevichyana435@gmail.com, группа: не указана
# Имя: Kondidat, email: niktakoteev09@gmail.com, группа: не указана
# Имя: micvk1404, email: vika19112005@mail.ru, группа: не указана
# Имя: Svetlana, email: svetasalmanovic@gmail.com, группа: не указана
# Имя: chernojopik, email: efimhlushko@gmail.com, группа: не указана
# Имя: Julien, email: juliettacrt@gmail.com, группа: не указана
# Имя: george_floud, email: orlov8028@gmail.com, группа: не указана
# Имя: Saka, email: nikitainfa09@gmail.com, группа: не указана
# Имя: Evgen, email: zixzix018@gmail.com, группа: не указана
# Имя: Dranik, email: danikgorodko228@gmail.com, группа: не указана
# Имя: Tanya, email: svketko@tut.by, группа: не указана
# Имя: chernish, email: zubmihpetr1337228@gmail.com, группа: не указана
# Имя: Беззубик Григорий, email: bezzubik_ga_20@mf.grsu.by, группа: КБ-201
# Имя: senikita, email: seniiknik@gmail.com, группа: не указана
# Имя: nikita, email: seniknik@gmail.com, группа: не указана
# Имя: vano, email: tregubov_ia_20@mf.grsu.by, группа: не указана
# Имя: Nikita155, email: sseniknik@gmail.com, группа: не указана
# Имя: Ivan, email: skorobogatov_is_20@mf.grsu.by, группа: не указана
# Имя: Ksenduna, email: kseniaphilli@mail.ru, группа: не указана
# Имя: Diegogo, email: axidore@gmai.ru, группа: не указана
# Имя: Diego, email: axidore@mail.ru, группа: не указана
# Имя: Петровский Дмитрий, email: petrovskij_dv_20@mf.grsu.by, группа: КБ-201
# Имя: TuGARiN, email: ovsyanik2004@gmail.com, группа: не указана
# Имя: abc, email: abc@internet.ru, группа: не указана
# Имя: a, email: roma703440@bk.ru, группа: не указана
# Имя: агент007, email: stomaanastasia27@gmail.com, группа: не указана
# Имя: Renatka, email: vasilevskayarenata08@gmail.com, группа: не указана
# Имя: EgOr4iK, email: egor.dovnar45729@gmail.com, группа: не указана
# Имя: Yana, email: klimukyana@gmail.com, группа: не указана
# Имя: Dasha, email: karkotadasa@gmail.com, группа: не указана
# Имя: Екатерина, email: katiamihnevich15@mail.ru, группа: не указана
# Имя: водим, email: vadimbuzhinsmij8@gmail.com, группа: не указана
# Имя: ., email: robertkurovsci23@gmail.com, группа: не указана
# Имя: Чипсики, email: leys-chipsy@mail.ru, группа: не указана
# Имя: Valeria, email: valeriagrituseva165@gmail.com, группа: не указана
# Имя: flomaster, email: master7793@mail.ru, группа: не указана
# Имя: 505505050005505050505050, email: prikolprikoo@gmail.com, группа: не указана
# Имя: diana4758, email: dianamakickaya@gmail.com, группа: не указана
# Имя: Nanfy__, email: margo3336822@gmail.com, группа: не указана
# Имя: nasstenika, email: anastasiadubravskaa@gmail.com, группа: не указана
# Имя: katya3241, email: avgutkata@gmail.com, группа: не указана
# Имя: viii, email: violetta598g@gmail.com, группа: не указана
# Имя: varya27, email: varvarka527@gmail.com, группа: не указана
# Имя: Ольга, email: janina.gudachevskaya@gmail.com, группа: не указана
# Имя: Маша, email: dashakrupskaya789@gmail.com, группа: не указана
# Имя: oleg, email: olegsidlarevic@gmail.com, группа: ty
# Имя: Юлия, email: sasha.evsutin@gmail.com, группа: не указана
# Имя: Ангелина, email: angelinastrykeli@gmail.com, группа: не указана
# Имя: mixl, email: olegsidler705@gmail.com, группа: не указана
# Имя: ocuroc, email: 04072006igor@gmail.com, группа: не указана
# Имя: Nicole, email: nikolikokik@gmail.com, группа: не указана
# Имя: ketko, email: svketko@gmail.com, группа: не указана
# Имя: JlLapxyH, email: dan200412@gmail.com, группа: не указана
# Имя: Симанович Роман, email: romansim03@mail.ru, группа: КБ-201
# Имя: darya, email: dstrakovskaya@gmail.com, группа: не указана
# Имя: timofey, email: nimonbot@gmail.com, группа: не указана
# Имя: Мурыгин Владислав, email: vladgrodno5@gmail.com, группа: КБ-201
# Имя: Лобазов Илья, email: agentlis001@gmail.com, группа: КБ-201
# Имя: Горошко Матвей, email: goroshko_md_20@mf.grsu.by, группа: КБ-201
# Имя: Лещук Максим, email: lexhuk_mo_19@mf.grsu.by, группа: КБ-191
# Имя: Каминский Никита, email: kaminskij_no_19@mf.grsu.by, группа: КБ-191
# Имя: Колячко Максим, email: kolychko_mv_19@mf.grsu.by, группа: КБ-191
# Имя: Скорябкин Артем, email: skorybkin_av_19@mf.grsu.by, группа: КБ-191
# Имя: Жарский Денис, email: zharskij_dp_19@mf.grsu.by, группа: КБ-191
# Имя: Дмитриев Владислав, email: dmitriev_vv_19@mf.grsu.by, группа: КБ-191
# Имя: Протосовицкая Софья, email: protosovickay_sb_19@mf.grsu.by, группа: КБ-191
# Имя: Рында Артем, email: rynda_an_19@mf.grsu.by, группа: КБ-191
# Имя: Бирич Павел, email: birich_pp_19@mf.grsu.by, группа: КБ-191
# Имя: Вдовенко Кирилл, email: vdovenko_ko_19@mf.grsu.by, группа: КБ-191
# Имя: Капицын Александр Андреевич, email: kapicyn_aa_19@mf.grsu.by, группа: КБ-191
# Имя: Дудич Николай, email: dudich_nj_19@mf.grsu.by, группа: КБ-191
# Имя: Клебча Антон, email: klebcha_an_19@mf.grsu.by, группа: КБ-191
# Имя: Соколов Алексей, email: sokolov_ao_19@mf.grsu.by, группа: КБ-191
# Имя: Яблонский Антон, email: yblonskij_ag_19@mf.grsu.by, группа: КБ-191
# Имя: Петушок Илья, email: petushok_ia_19@mf.grsu.by, группа: КБ-191
# Имя: Высоцкий Егор, email: vysockij_eo_19@mf.grsu.by, группа: КБ-191
# Имя: Сильванович Иван, email: silvanovich_iy_19@mf.grsu.by, группа: КБ-191
# Имя: Котелков Антон, email: kotelkov_ad_19@student.grsu.by, группа: КБ-191
# Имя: Юдин Георгий, email: jdin_gv_19@mf.grsu.by, группа: КБ-191
# Имя: Касьян Алексей, email: kasyn_av_19@mf.grsu.by, группа: КБ-191
# Имя: Хомбак Андрей, email: xombak_aa_19@mf.grsu.by, группа: КБ-191
# Имя: Рубец Владимир, email: rubec_vs_19@mf.grsu.by, группа: КБ-191
# Имя: Artiksn, email: artemgame20375@gmail.com, группа: не указана
# Имя: Михалюк Денис, email: denis.mixaluk@gmail.com, группа: КБ-201
# Имя: Ksen, email: lenaksena50@gmail.com, группа: не указана
# Имя: Roman_Simanovich, email: simanovich_rs_20@mf.grsu.by, группа: КБ-201
# Имя: Akineyshen, email: maksim.vasuhnevich@mail.ru, группа: не указана
# Имя: MVasuhnevich, email: maksim.vasuhnevich@gmail.com, группа: не указана
# Имя: Булай Алеся, email: bulaj_ae_19@mf.grsu.by, группа: КБ-191
# Имя: Косогов Илья, email: kosogov.ilyaa@mail.ru, группа: не указана
# Имя: Borsuk Daniil, email: borsuk_dp_20@mf.grsu.by, группа: не указана
# Имя: User935, email: 935.nikita@gmail.com, группа: не указана
# Имя: Булгаков Роман, email: bulgakov_ra_19@mf.grsu.by, группа: КБ-191
# Имя: Andrei Varuyeu, email: varuyeu@gmail.com, группа: не указана
# Имя: Kostya, email: tsivilko02@mail.ru, группа: не указана
# Имя: Никита Ходарёнок, email: nikitahodarenok@gmail.com, группа: не указана
# Имя: Pavel, email: pavel.radush@mail.ru, группа: не указана
# Имя: RunOrFight, email: dragoinfury@gmail.com, группа: не указана
# Имя: vdmglkv, email: gulakov.vadim2017@yandex.ru, группа: не указана
# Имя: ja.pucicki, email: ja.pucicki@outlook.com, группа: не указана
# Имя: Aleaksei, email: a.golosnoy@list.ru, группа: не указана
# Имя: aliadv, email: sasha.dv2000@gmail.com, группа: не указана
# Имя: anakilivo, email: anakilivo@gmail.com, группа: не указана
# Имя: Мартынюк Роман, email: martynjk_rm_20@mf.grsu.by, группа: КБ-201
# Имя: Базыльчик Александр, email: bazylchyk.a@gmail.com, группа: КБ-201
# Имя: Вашкелевич Павел, email: vashkelevich_pv_20@mf.grsu.by, группа: КБ-201
# Имя: Косач Вадим, email: kosach_vs_20@mf.grsu.by, группа: КБ-201
# Имя: Драчёв Ярослав, email: drachev_yv_20@mf.grsu.by, группа: КБ-201
# Имя: Трегубов Иван, email: tregoubov@bk.ru, группа: КБ-201
# Имя: Горбач Максим, email: gorbach_ms_20@mf.grsu.by, группа: КБ-201
# Имя: Гурский Евгений, email: gurskij_eo_20@mf.grsu.by, группа: КБ-201
# Имя: Козляк Тимофей, email: lgfdsfsddsfsdfs@gmail.com, группа: КБ-201
# Имя: Демещик Максим, email: maks.demeshik@mail.ru, группа: КБ-201
# Имя: Мицкевич Станислав, email: kin-son@mail.ru, группа: не указана
# Имя: bot, email: testwordpress.number1@gmail.com, группа: не указана
# Имя: Ременчик Евгений, email: remenchik_ej_20@mf.grsu.by, группа: КБ-201
# Имя: Кореневский Никита, email: nikita.koren2002@gmail.com, группа: КБ-201
# Имя: Максим Демидович, email: demidovich_ma_19@mf.grsu.by, группа: не указана
# Имя: Belogolovay_NV_18, email: belogolovay_nv_18@mf.grsu.by, группа: не указана
# Имя: Oleg.Myslivets, email: myslivec_or@mf.grsu.by, группа: не указана
# Имя: Sashka, email: maskevich_ai_19@mf.grsu.by, группа: не указана
# Имя: Александр Маскевич, email: maskevichaleksandr33@gmail.com, группа: КБ-191
# Имя: Asiya, email: nastia.rynkevich@gmail.com, группа: не указана
# Имя: kosmos, email: kosmos146139@gmail.com, группа: не указана
# Имя: Half.Teacher, email: half.teacher@protonmail.com, группа: не указана
# Имя: testTanya, email: Tanya@gmail.com, группа: не указана
# Имя: testGutsko, email: Gutsko@gmail.com, группа: не указана
#
# Количество студентов в системе из каждой группы:
# У 128 человек в системе группа не указана
# Группа "КБ-201" - 27 человек в системе
# Группа "Вороновская Средняя Школа" - 1 человек в системе
# Группа "ty" - 1 человек в системе
# Группа "КБ-191" - 26 человек в системе

# %%
#ВЫВОД СТУДЕНТОВ ОПРЕДЕЛЕННОЙ ГРУППЫ

import json

with open('E:/course work/CTF MF.2022-02-10/db/users.json') as file:
    f = file.read()
    data = json.loads(f)
group = input("Введите группу: ")

numStud = 0
for text in data['results']:
    if text['affiliation'] == group:
        print(text['name'], ':', text['email'])
        numStud += 1

if numStud == 0:
    print(f"Студентов группы {group} нет в системе. Проверьте введенные данные")
else:
    print(f"Количество студентов группы {group} в системе: {numStud}")
# Out:
# Введите группу: КБ-191
# Лещук Максим : lexhuk_mo_19@mf.grsu.by
# Каминский Никита : kaminskij_no_19@mf.grsu.by
# Колячко Максим : kolychko_mv_19@mf.grsu.by
# Скорябкин Артем : skorybkin_av_19@mf.grsu.by
# Жарский Денис : zharskij_dp_19@mf.grsu.by
# Дмитриев Владислав : dmitriev_vv_19@mf.grsu.by
# Протосовицкая Софья : protosovickay_sb_19@mf.grsu.by
# Рында Артем : rynda_an_19@mf.grsu.by
# Бирич Павел : birich_pp_19@mf.grsu.by
# Вдовенко Кирилл : vdovenko_ko_19@mf.grsu.by
# Капицын Александр Андреевич : kapicyn_aa_19@mf.grsu.by
# Дудич Николай : dudich_nj_19@mf.grsu.by
# Клебча Антон : klebcha_an_19@mf.grsu.by
# Соколов Алексей : sokolov_ao_19@mf.grsu.by
# Яблонский Антон : yblonskij_ag_19@mf.grsu.by
# Петушок Илья : petushok_ia_19@mf.grsu.by
# Высоцкий Егор : vysockij_eo_19@mf.grsu.by
# Сильванович Иван : silvanovich_iy_19@mf.grsu.by
# Котелков Антон : kotelkov_ad_19@student.grsu.by
# Юдин Георгий : jdin_gv_19@mf.grsu.by
# Касьян Алексей : kasyn_av_19@mf.grsu.by
# Хомбак Андрей : xombak_aa_19@mf.grsu.by
# Рубец Владимир : rubec_vs_19@mf.grsu.by
# Булай Алеся : bulaj_ae_19@mf.grsu.by
# Булгаков Роман : bulgakov_ra_19@mf.grsu.by
# Александр Маскевич : maskevichaleksandr33@gmail.com
# Количество студентов группы КБ-191 в системе: 26

# %%
#ВЫВОД КОЛИЧЕСТВА ПРАВИЛЬНЫХ ОТВЕТОВ У ВСЕХ ПОЛЬЗОВЕТЕЛЕЙ

import json

with open('E:/course work/CTF MF.2022-02-10/db/users.json') as file:
    f = file.read()
    users = json.loads(f)

with open('E:/course work/CTF MF.2022-02-10/db/solves.json') as file:
    f = file.read()
    solves = json.loads(f)
    
    for x in users['results']:
        result = 0
        for y in solves['results']:
            if x['id'] == y['user_id']:
                result = result+1
        print(x['name'], ':', x['email'], ':', result)
# Out:
# admin : admin@admin.com : 0
# dirvuk : dirvuk@gmail.com : 0
# Urbanovich_AI : urbanovichwork@gmail.com : 0
# kadan : kadan@mf.grsu.by : 5
# testuser : small@mf.grsu.by : 0
# ctfeditor : ctf@mf.grsu.by : 0
# ethnia : taranko.ev@mf.grsu.by : 0
# Palina Platava : platova_po_16@mf.grsu.by : 0
# Vladimir Shilko : shilko02@inbox.ru : 0
# Maximilin : ynulevich_mv_20@mf.grsu.by : 0
# nimon : kozlyk_te_20@mf.grsu.by : 0
# Каревский Арсентий : karevskij_aa_20@mf.grsu.by : 123
# Куликов Дмитрий : kulikov_da_20@mf.grsu.by : 148
# Лелевич Алексей : lelevich_ag_20@mf.grsu.by : 160
# Alice : alica.lancraft@gmail.com : 177
# Maks : karpeychik.maks@mail.ru : 0
# Kedel Yuliya : kedel_ja_19@mf.grsu.by : 0
# Victoria : podstavskay_vd_19@mf.grsu.by : 0
# IvanMur : mureny_iv_19@mf.grsu.by : 0
# Nastya : rust_aa_19@mf.grsu.by : 0
# Alexander : kuryn_aj_19@mf.grsu.by : 0
# Taras : tarasova_na_19@mf.grsu.by : 0
# Vika : sljsareva_vr_19@mf.grsu.by : 0
# Даниил Логин : logindaniil333@gmail.com : 0
# Zazar : kartashevich_zl_19@mf.grsu.by : 0
# Юрий : krupich_jm_19@mf.grsu.by : 0
# Maxanko Maxim : maxanko_mv_20@mf.grsu.by : 0
# Новиков Родион : rodion.novikov.2002@mail.ru : 129
# Валера : cidikvalera@gmail.com : 0
# Клеменя Алеся : klemeny_ap_20@mf.grsu.by : 105
# Санько Дмитрий : sanko_ds_20@mf.grsu.by : 148
# Tatiana : tatushonok@mail.ru : 0
# Скоробогатов Иван : skorobogatov_is_20@cs.mf.grsu.by : 116
# Evgen Fizik : woishnis@mail.ru : 0
# OMG : zolga20@gmail.com : 0
# Matvey : matvej.yakovenko@gmail.com : 0
# viktoria : vikkovalchuk25@email.com : 0
# Maksimovich Denis : dm2094068@gmail.com : 0
# Arina : yamabukisayo@gmail.com : 0
# polina : basalaypolina2007@gmail.com : 0
# ksenia : kseniaanuskevic510@gmail.com : 0
# Lera : dingilevskaalera@gmail.com : 0
# Дарья Катанекша : dkataneksha00@mail.ru : 0
# VitalyaArmatura : master7793@gmail.com : 0
# ViacheslavCyberMan : leogiss04@mail.ru : 0
# OLEG-KIBORG : oleshkahotyanovich@mail.ru : 0
# Tuzenciy : andrej@matujzo.of.by : 0
# Daria Markel : daskamarkel@gmail.com : 0
# Ovest : cladcladclad@mail.ru : 0
# дмитрий кухта : kuhta26@mail.ru : 0
# anonim : adriansatalin@gmail.com : 0
# igorrunin : igorrunin222@mail.ru : 0
# EVG : evgenvoishnis@gmail.com : 0
# OnlyBlack#1992 : steamng228@gmail.com : 0
# собака : grhziwxhvs@gmail.com : 0
# daan : olgak5176@gmail.com : 0
# читос с сыром : lukashevichyana435@gmail.com : 0
# Kondidat : niktakoteev09@gmail.com : 0
# micvk1404 : vika19112005@mail.ru : 0
# Svetlana : svetasalmanovic@gmail.com : 0
# chernojopik : efimhlushko@gmail.com : 0
# Julien : juliettacrt@gmail.com : 0
# george_floud : orlov8028@gmail.com : 0
# Saka : nikitainfa09@gmail.com : 0
# Evgen : zixzix018@gmail.com : 0
# Dranik : danikgorodko228@gmail.com : 0
# Tanya : svketko@tut.by : 0
# chernish : zubmihpetr1337228@gmail.com : 0
# Беззубик Григорий : bezzubik_ga_20@mf.grsu.by : 170
# senikita : seniiknik@gmail.com : 0
# nikita : seniknik@gmail.com : 0
# vano : tregubov_ia_20@mf.grsu.by : 0
# Nikita155 : sseniknik@gmail.com : 0
# Ivan : skorobogatov_is_20@mf.grsu.by : 0
# Ksenduna : kseniaphilli@mail.ru : 0
# Diegogo : axidore@gmai.ru : 0
# Diego : axidore@mail.ru : 0
# Петровский Дмитрий : petrovskij_dv_20@mf.grsu.by : 164
# TuGARiN : ovsyanik2004@gmail.com : 0
# abc : abc@internet.ru : 0
# a : roma703440@bk.ru : 0
# агент007 : stomaanastasia27@gmail.com : 0
# Renatka : vasilevskayarenata08@gmail.com : 0
# EgOr4iK : egor.dovnar45729@gmail.com : 0
# Yana : klimukyana@gmail.com : 0
# Dasha : karkotadasa@gmail.com : 0
# Екатерина : katiamihnevich15@mail.ru : 0
# водим : vadimbuzhinsmij8@gmail.com : 0
# . : robertkurovsci23@gmail.com : 0
# Чипсики : leys-chipsy@mail.ru : 0
# Valeria : valeriagrituseva165@gmail.com : 0
# flomaster : master7793@mail.ru : 0
# 505505050005505050505050 : prikolprikoo@gmail.com : 0
# diana4758 : dianamakickaya@gmail.com : 0
# Nanfy__ : margo3336822@gmail.com : 0
# nasstenika : anastasiadubravskaa@gmail.com : 0
# katya3241 : avgutkata@gmail.com : 0
# viii : violetta598g@gmail.com : 0
# varya27 : varvarka527@gmail.com : 0
# Ольга : janina.gudachevskaya@gmail.com : 0
# Маша : dashakrupskaya789@gmail.com : 0
# oleg : olegsidlarevic@gmail.com : 0
# Юлия : sasha.evsutin@gmail.com : 0
# Ангелина : angelinastrykeli@gmail.com : 0
# mixl : olegsidler705@gmail.com : 0
# ocuroc : 04072006igor@gmail.com : 0
# Nicole : nikolikokik@gmail.com : 0
# ketko : svketko@gmail.com : 0
# JlLapxyH : dan200412@gmail.com : 0
# Симанович Роман : romansim03@mail.ru : 146
# darya : dstrakovskaya@gmail.com : 0
# timofey : nimonbot@gmail.com : 0
# Мурыгин Владислав : vladgrodno5@gmail.com : 115
# Лобазов Илья : agentlis001@gmail.com : 133
# Горошко Матвей : goroshko_md_20@mf.grsu.by : 151
# Лещук Максим : lexhuk_mo_19@mf.grsu.by : 83
# Каминский Никита : kaminskij_no_19@mf.grsu.by : 55
# Колячко Максим : kolychko_mv_19@mf.grsu.by : 52
# Скорябкин Артем : skorybkin_av_19@mf.grsu.by : 69
# Жарский Денис : zharskij_dp_19@mf.grsu.by : 66
# Дмитриев Владислав : dmitriev_vv_19@mf.grsu.by : 56
# Протосовицкая Софья : protosovickay_sb_19@mf.grsu.by : 73
# Рында Артем : rynda_an_19@mf.grsu.by : 62
# Бирич Павел : birich_pp_19@mf.grsu.by : 60
# Вдовенко Кирилл : vdovenko_ko_19@mf.grsu.by : 78
# Капицын Александр Андреевич : kapicyn_aa_19@mf.grsu.by : 68
# Дудич Николай : dudich_nj_19@mf.grsu.by : 69
# Клебча Антон : klebcha_an_19@mf.grsu.by : 67
# Соколов Алексей : sokolov_ao_19@mf.grsu.by : 64
# Яблонский Антон : yblonskij_ag_19@mf.grsu.by : 54
# Петушок Илья : petushok_ia_19@mf.grsu.by : 52
# Высоцкий Егор : vysockij_eo_19@mf.grsu.by : 38
# Сильванович Иван : silvanovich_iy_19@mf.grsu.by : 68
# Котелков Антон : kotelkov_ad_19@student.grsu.by : 84
# Юдин Георгий : jdin_gv_19@mf.grsu.by : 64
# Касьян Алексей : kasyn_av_19@mf.grsu.by : 67
# Хомбак Андрей : xombak_aa_19@mf.grsu.by : 73
# Рубец Владимир : rubec_vs_19@mf.grsu.by : 69
# Artiksn : artemgame20375@gmail.com : 0
# Михалюк Денис : denis.mixaluk@gmail.com : 111
# Ksen : lenaksena50@gmail.com : 0
# Roman_Simanovich : simanovich_rs_20@mf.grsu.by : 0
# Akineyshen : maksim.vasuhnevich@mail.ru : 0
# MVasuhnevich : maksim.vasuhnevich@gmail.com : 0
# Булай Алеся : bulaj_ae_19@mf.grsu.by : 84
# Косогов Илья : kosogov.ilyaa@mail.ru : 0
# Borsuk Daniil : borsuk_dp_20@mf.grsu.by : 0
# User935 : 935.nikita@gmail.com : 0
# Булгаков Роман : bulgakov_ra_19@mf.grsu.by : 55
# Andrei Varuyeu : varuyeu@gmail.com : 0
# Kostya : tsivilko02@mail.ru : 0
# Никита Ходарёнок : nikitahodarenok@gmail.com : 0
# Pavel : pavel.radush@mail.ru : 0
# RunOrFight : dragoinfury@gmail.com : 0
# vdmglkv : gulakov.vadim2017@yandex.ru : 0
# ja.pucicki : ja.pucicki@outlook.com : 0
# Aleaksei : a.golosnoy@list.ru : 0
# aliadv : sasha.dv2000@gmail.com : 0
# anakilivo : anakilivo@gmail.com : 190
# Мартынюк Роман : martynjk_rm_20@mf.grsu.by : 102
# Базыльчик Александр : bazylchyk.a@gmail.com : 157
# Вашкелевич Павел : vashkelevich_pv_20@mf.grsu.by : 128
# Косач Вадим : kosach_vs_20@mf.grsu.by : 107
# Драчёв Ярослав : drachev_yv_20@mf.grsu.by : 115
# Трегубов Иван : tregoubov@bk.ru : 74
# Горбач Максим : gorbach_ms_20@mf.grsu.by : 122
# Гурский Евгений : gurskij_eo_20@mf.grsu.by : 121
# Козляк Тимофей : lgfdsfsddsfsdfs@gmail.com : 131
# Демещик Максим : maks.demeshik@mail.ru : 142
# Мицкевич Станислав : kin-son@mail.ru : 13
# bot : testwordpress.number1@gmail.com : 0
# Ременчик Евгений : remenchik_ej_20@mf.grsu.by : 100
# Кореневский Никита : nikita.koren2002@gmail.com : 70
# Максим Демидович : demidovich_ma_19@mf.grsu.by : 41
# Belogolovay_NV_18 : belogolovay_nv_18@mf.grsu.by : 3
# Oleg.Myslivets : myslivec_or@mf.grsu.by : 0
# Sashka : maskevich_ai_19@mf.grsu.by : 12
# Александр Маскевич : maskevichaleksandr33@gmail.com : 44
# Asiya : nastia.rynkevich@gmail.com : 13
# kosmos : kosmos146139@gmail.com : 4
# Half.Teacher : half.teacher@protonmail.com : 29
# testTanya : Tanya@gmail.com : 1
# testGutsko : Gutsko@gmail.com : 1

# %%
#ВЫВОД ПОЛЬЗОВАТЕЛЯ С НАИБОЛЬШИМ КОЛИЧЕСТВОМ РЕШЕННЫХ ЗАДАЧ

import json

with open('E:/course work/CTF MF.2022-02-10/db/users.json') as file:
    f = file.read()
    users = json.loads(f)

with open('E:/course work/CTF MF.2022-02-10/db/solves.json') as file:
    f = file.read()
    solves = json.loads(f)

max = 0
for x in users['results']:
    result = 0
    for y in solves['results']:
        if x['id'] == y['user_id']:
            result = result + 1
    if result >= max:
        winner = x
        max = result
print(winner['name'], ':', winner['email'], '-', max)
# Out:
# anakilivo : anakilivo@gmail.com - 190

# %%
#ВЫВОД 3 ПОЛЬЗОВАТЕЛЕЙ С НАИБОЛЬШИМ КОЛИЧЕСТВОМ РЕШЕННЫХ ЗАДАЧ

import json

with open('E:/course work/CTF MF.2022-02-10/db/users.json') as file:
    f = file.read()
    users = json.loads(f)

with open('E:/course work/CTF MF.2022-02-10/db/solves.json') as file:
    f = file.read()
    solves = json.loads(f)

res = dict()
for x in users['results']:
    result = 0
    for y in solves['results']:
        if x['id'] == y['user_id']:
            result = result + 1
    res[x['name']] = result

sorted_tuple = sorted(res.items(), key=lambda x: x[1])
sorted_dict = dict(sorted_tuple)
for key in sorted_dict:
    print(f"{key} - {sorted_dict[key]}")

length = len(sorted_dict)
print('Всего студентов в системе:' , length)

max1 = sorted(sorted_dict.values())[-1]
max2 = sorted(sorted_dict.values())[-2]
max3 = sorted(sorted_dict.values())[-3]

for key, value in sorted_dict.items():
    if value == max1:
        for user in users['results']:
            if user['name'] == key:
                win_email = user['email']
        print(f"1 место по количеству решенных задач: {key} =  {value}, почта: {win_email}")
    if value == max2:
        for user in users['results']:
            if user['name'] == key:
                win_email = user['email']
        print(f"2 место по количеству решенных задач: {key} =  {value}, почта: {win_email}")
    if value == max3:
        for user in users['results']:
            if user['name'] == key:
                win_email = user['email']
        print(f"3 место по количеству решенных задач: {key} =  {value}, почта: {win_email}")
# Out:
# admin - 0
# dirvuk - 0
# Urbanovich_AI - 0
# testuser - 0
# ctfeditor - 0
# ethnia - 0
# Palina Platava - 0
# Vladimir Shilko - 0
# Maximilin - 0
# nimon - 0
# Maks - 0
# Kedel Yuliya - 0
# Victoria - 0
# IvanMur - 0
# Nastya - 0
# Alexander - 0
# Taras - 0
# Vika - 0
# Даниил Логин - 0
# Zazar - 0
# Юрий - 0
# Maxanko Maxim - 0
# Валера - 0
# Tatiana - 0
# Evgen Fizik - 0
# OMG - 0
# Matvey - 0
# viktoria - 0
# Maksimovich Denis - 0
# Arina - 0
# polina - 0
# ksenia - 0
# Lera - 0
# Дарья Катанекша - 0
# VitalyaArmatura - 0
# ViacheslavCyberMan - 0
# OLEG-KIBORG - 0
# Tuzenciy - 0
# Daria Markel - 0
# Ovest - 0
# дмитрий кухта - 0
# anonim - 0
# igorrunin - 0
# EVG - 0
# OnlyBlack#1992 - 0
# собака - 0
# daan - 0
# читос с сыром - 0
# Kondidat - 0
# micvk1404 - 0
# Svetlana - 0
# chernojopik - 0
# Julien - 0
# george_floud - 0
# Saka - 0
# Evgen - 0
# Dranik - 0
# Tanya - 0
# chernish - 0
# senikita - 0
# nikita - 0
# vano - 0
# Nikita155 - 0
# Ivan - 0
# Ksenduna - 0
# Diegogo - 0
# Diego - 0
# TuGARiN - 0
# abc - 0
# a - 0
# агент007 - 0
# Renatka - 0
# EgOr4iK - 0
# Yana - 0
# Dasha - 0
# Екатерина - 0
# водим - 0
# . - 0
# Чипсики - 0
# Valeria - 0
# flomaster - 0
# 505505050005505050505050 - 0
# diana4758 - 0
# Nanfy__ - 0
# nasstenika - 0
# katya3241 - 0
# viii - 0
# varya27 - 0
# Ольга - 0
# Маша - 0
# oleg - 0
# Юлия - 0
# Ангелина - 0
# mixl - 0
# ocuroc - 0
# Nicole - 0
# ketko - 0
# JlLapxyH - 0
# darya - 0
# timofey - 0
# Artiksn - 0
# Ksen - 0
# Roman_Simanovich - 0
# Akineyshen - 0
# MVasuhnevich - 0
# Косогов Илья - 0
# Borsuk Daniil - 0
# User935 - 0
# Andrei Varuyeu - 0
# Kostya - 0
# Никита Ходарёнок - 0
# Pavel - 0
# RunOrFight - 0
# vdmglkv - 0
# ja.pucicki - 0
# Aleaksei - 0
# aliadv - 0
# bot - 0
# Oleg.Myslivets - 0
# testTanya - 1
# testGutsko - 1
# Belogolovay_NV_18 - 3
# kosmos - 4
# kadan - 5
# Sashka - 12
# Мицкевич Станислав - 13
# Asiya - 13
# Half.Teacher - 29
# Высоцкий Егор - 38
# Максим Демидович - 41
# Александр Маскевич - 44
# Колячко Максим - 52
# Петушок Илья - 52
# Яблонский Антон - 54
# Каминский Никита - 55
# Булгаков Роман - 55
# Дмитриев Владислав - 56
# Бирич Павел - 60
# Рында Артем - 62
# Соколов Алексей - 64
# Юдин Георгий - 64
# Жарский Денис - 66
# Клебча Антон - 67
# Касьян Алексей - 67
# Капицын Александр Андреевич - 68
# Сильванович Иван - 68
# Скорябкин Артем - 69
# Дудич Николай - 69
# Рубец Владимир - 69
# Кореневский Никита - 70
# Протосовицкая Софья - 73
# Хомбак Андрей - 73
# Трегубов Иван - 74
# Вдовенко Кирилл - 78
# Лещук Максим - 83
# Котелков Антон - 84
# Булай Алеся - 84
# Ременчик Евгений - 100
# Мартынюк Роман - 102
# Клеменя Алеся - 105
# Косач Вадим - 107
# Михалюк Денис - 111
# Мурыгин Владислав - 115
# Драчёв Ярослав - 115
# Скоробогатов Иван - 116
# Гурский Евгений - 121
# Горбач Максим - 122
# Каревский Арсентий - 123
# Вашкелевич Павел - 128
# Новиков Родион - 129
# Козляк Тимофей - 131
# Лобазов Илья - 133
# Демещик Максим - 142
# Симанович Роман - 146
# Куликов Дмитрий - 148
# Санько Дмитрий - 148
# Горошко Матвей - 151
# Базыльчик Александр - 157
# Лелевич Алексей - 160
# Петровский Дмитрий - 164
# Беззубик Григорий - 170
# Alice - 177
# anakilivo - 190
# Всего студентов в системе: 183
# 3 место по количеству решенных задач: Беззубик Григорий =  170, почта: bezzubik_ga_20@mf.grsu.by
# 2 место по количеству решенных задач: Alice =  177, почта: alica.lancraft@gmail.com
# 1 место по количеству решенных задач: anakilivo =  190, почта: anakilivo@gmail.com

# %%
#ВЫВОД ТЕХ, КТО ВОШЕЛ ПОД ОДНИМ IP В ОДИН ДЕНЬ

import json
from datetime import datetime

with open('E:/course work/CTF MF.2022-02-10/db/tracking.json') as file:
    f = file.read()
    tracking = json.loads(f)

with open('E:/course work/CTF MF.2022-02-10/db/users.json') as file:
    f = file.read()
    users = json.loads(f)

for text in tracking['results']:
    for t in tracking['results']:
        text_date = datetime.fromisoformat((text['date'])).strftime('%Y-%m-%d')
        t_date = datetime.fromisoformat((t['date'])).strftime('%Y-%m-%d')
        if text['ip'] == t['ip'] and text['user_id'] != t['user_id'] and text_date == t_date and text['user_id'] < t['user_id']:
            for y in users['results']:
                if text['user_id'] == y['id']:
                    first = y['name']
                if t['user_id'] == y['id']:
                    second = y['name']

            print(f"{datetime.fromisoformat((text['date'])).strftime('%d %B %Y')} {first} (id: {text['user_id']}) и {second} (id: {t['user_id']}) вошли под одним IP: {text['ip']}")

# %%
#ВЫВОД ПОЛЬЗОВАТЕЛЕЙ, У КОТОРЫХ ВСЕ ОТВЕТЫ ПРАВИЛЬНЫЕ С ПЕРВОЙ ПОПЫТКИ

import json

with open('E:/course work/CTF MF.2022-02-10/db/users.json') as file:
    f = file.read()
    users = json.loads(f)

with open('E:/course work/CTF MF.2022-02-10/db/submissions.json') as file:
    f = file.read()
    submissions = json.loads(f)

    for x in users['results']:
        inccorect_answers = 0
        all_answers = 0
        for y in submissions['results']:
            if x['id'] == y['user_id']:
                all_answers += 1
                if y['type'] == 'incorrect':
                    inccorect_answers += 1

        if inccorect_answers == 0 and all_answers != 0:
            print(f"У {x['name']} нет неправильных ответов из {all_answers} решенных задач")
# Out:
# У Alice нет неправильных ответов из 177 решенных задач
# У anakilivo нет неправильных ответов из 190 решенных задач
# У kosmos нет неправильных ответов из 4 решенных задач
# У testGutsko нет неправильных ответов из 2 решенных задач

# %%
#ЗАДАЧА, КОТОРУЮ ЧАЩЕ ВСЕГО РЕШАЮТ НЕВЕРНО

import json

with open('E:/course work/CTF MF.2022-02-10/db/challenges.json') as file:
    f = file.read()
    challenges = json.loads(f)

with open('E:/course work/CTF MF.2022-02-10/db/submissions.json') as file:
    f = file.read()
    submissions = json.loads(f)

max = 0
for x in challenges['results']:
    count = 0
    for y in submissions['results']:
        if x['id'] == y['challenge_id'] and y['type'] == 'incorrect':
            count += 1

    if(count > max):
        max = count
        winner = x

print (f"Задачу {winner['id']} решили неправильно {max} раз. \nЗадача \"{winner['name']}\": \n{winner['description']}")
# Out:
# Задачу 68 решили неправильно 296 раз.
# Задача "Забытая кодировка":
# Вчера главный специалист Вера Ипполитовна по ошибке сохранила русский текст в своей любимой кодировке:
#
# **╨Т╤Б╨╡╨╝ ╨╖╨┤╨░╤А╨╛╨▓╨░! ╨Я╤А╨╡╨┤╤Б╤В╨░╨▓╨╗╤П╨╡╨╝ ╨╜╨░╤И ╨╜╨╛╨▓╤Л╨╣ ╨д╨╗╨░╨│: ╤В╤А╨╕ ╤И╨╡╤Б╤В╤М ╤И╨╡╤Б╤В╤М ╤Б╨╡╨╝╤М ╨╜╨╛╨╗╤М ╨┤╨▓╨░ ╨▓╨╛╤Б╨╡╨╝╤М**
#
# Как вы думаете, давно Вера Ипполитовна работает за компьютером ?
#
# Ответом на задание будет обозначение любимой кодировки Веры Ипполитовны

# %%
#В КАКОЙ ДЕНЬ НЕДЕЛИ ЧАЩЕ РЕШАЮТ ЗАДАЧИ

import calendar
import json
from datetime import datetime


def WeekDayRus (text):
    if text == "Monday":
        return "Понедельник"
    if text == "Tuesday":
        return "Вторник"
    if text == "Wednesday":
        return "Среда"
    if text == "Thursday":
        return "Четверг"
    if text == "Friday":
        return "Пятница"
    if text == "Saturday":
        return "Суббота"
    if text == "Sunday":
        return "Воскресенье"

with open('E:/course work/CTF MF.2022-02-10/db/submissions.json') as file:
    f = file.read()
    submissions = json.loads(f)

days = dict()
for data in submissions['results']:
    text_date = datetime.fromisoformat((data['date'])).strftime('%Y-%m-%d')
    dayOfWeek = datetime.strptime(text_date, '%Y-%m-%d').weekday()
    if dayOfWeek in days.keys():
        days[dayOfWeek] += 1
    else:
        days[dayOfWeek] = 1

for key, value in days.items():
    if max(days.values()) == value:
        dayRus = WeekDayRus(calendar.day_name[key])
        print(f"День недели, в который пользователи проявляют наибольшую активность: {dayRus}")

    if min(days.values()) == value:
        dayRus = WeekDayRus(calendar.day_name[key])
        print(f"День недели, в который пользователи проявляют наименьшую активность: {dayRus}")
# Out:
# День недели, в который пользователи проявляют наименьшую активность: Суббота
# День недели, в который пользователи проявляют наибольшую активность: Вторник

# %%
#В КАКОЕ ВРЕМЯ ДНЯ ЧАЩЕ РЕШАЮТ

import json
from datetime import datetime

with open('E:/course work/CTF MF.2022-02-10/db/submissions.json') as file:
    f = file.read()
    submissions = json.loads(f)

times = dict()
for data in submissions['results']:
    text_time = datetime.fromisoformat((data['date'])).strftime('%H')
    hour = int(text_time)

    if hour in times.keys():
        times[hour] += 1
    else:
        times[hour] = 1

winner = max(times.values())
for key, value in times.items():
    if winner == value:
        print(f"Наибольшую активность пользователи проявляют в период времени с {key} до {key+1} часов")
# Out:
# Наибольшую активность пользователи проявляют в период времени с 9 до 10 часов

# %%
#У ДВУХ ПОЛЬЗОВАТЕЛЕЙ РЕШЕНЫ ОДИНАКОВЫЕ ЗАДАЧИ

import json

def printgroup(gr):
    if gr is not None:
        return gr
    else:
        return ''

with open('E:/course work/CTF MF.2022-02-10/db/solves.json') as file:
    f = file.read()
    solves = json.loads(f)

with open('E:/course work/CTF MF.2022-02-10/db/users.json') as file:
    f = file.read()
    users = json.loads(f)

for x in users['results']:
    for y in users['results']:
        listX = list()
        listY = list()
        if x['id'] < y['id']:
            for data in solves['results']:
                if x['id'] == data['user_id']:
                    listX.append(data['challenge_id'])
                if y['id'] == data['user_id']:
                    listY.append(data['challenge_id'])

        listX.sort()
        listY.sort()
        if len(listX) != 0 and len(listY) != 0:
            if listX == listY:
                print(f"У {x['name']} - {printgroup(x['affiliation'])} и {y['name']} - {printgroup(y['affiliation'])} решены одинаковые задачи (всего {len(listX)})")
# Out:
# У Скорябкин Артем - КБ-191 и Дудич Николай - КБ-191 решены одинаковые задачи (всего 69)
# У Скорябкин Артем - КБ-191 и Рубец Владимир - КБ-191 решены одинаковые задачи (всего 69)
# У Дудич Николай - КБ-191 и Рубец Владимир - КБ-191 решены одинаковые задачи (всего 69)
# У testTanya -  и testGutsko -  решены одинаковые задачи (всего 1)

# %%
#ВЫВОД ПОЛЬЗОВАТЕЛЕЙ, У КОТОРЫХ БЫСТРО РЕШАЮТСЯ ЗАДАЧИ

import json
from datetime import datetime
from datetime import timedelta

with open('E:/course work/CTF MF.2022-02-10/db/users.json') as file:
    f = file.read()
    users = json.loads(f)

with open('E:/course work/CTF MF.2022-02-10/db/submissions.json') as file:
    f = file.read()
    submissions = json.loads(f)

print("Пользователи, решившие задания за время, меньшее чем 2 минуты:")
for user in users['results']:
    listOftimes = list()
    for data in submissions['results']:
        if user['id'] == data['user_id'] and data['type'] == 'correct':
            text_time = datetime.fromisoformat((data['date'])).strftime('%y-%m-%d %H:%M:%S')
            time = datetime.strptime(text_time, '%y-%m-%d %H:%M:%S')
            listOftimes.append(time)

    count = 0
    oops = 1
    if len(listOftimes) != 0:
        while count <= len(listOftimes)-2:
            if listOftimes[count+1]-listOftimes[count] <= timedelta(minutes=2):
                oops += 1
            count += 1
        if oops != 1:
            print(f"Пользователь {user['name']} (id: {user['id']}) решил {oops} вопросов из {len(listOftimes)} решенных удивительно быстро")
# Out:
# Пользователи, решившие задания за время, меньшее чем 2 минуты:
# Пользователь kadan (id: 5) решил 3 вопросов из 5 решенных удивительно быстро
# Пользователь Каревский Арсентий (id: 13) решил 58 вопросов из 123 решенных удивительно быстро
# Пользователь Куликов Дмитрий (id: 14) решил 31 вопросов из 148 решенных удивительно быстро
# Пользователь Лелевич Алексей (id: 15) решил 52 вопросов из 160 решенных удивительно быстро
# Пользователь Alice (id: 16) решил 62 вопросов из 177 решенных удивительно быстро
# Пользователь Новиков Родион (id: 29) решил 55 вопросов из 129 решенных удивительно быстро
# Пользователь Клеменя Алеся (id: 31) решил 28 вопросов из 105 решенных удивительно быстро
# Пользователь Санько Дмитрий (id: 32) решил 54 вопросов из 148 решенных удивительно быстро
# Пользователь Скоробогатов Иван (id: 34) решил 75 вопросов из 116 решенных удивительно быстро
# Пользователь Беззубик Григорий (id: 73) решил 31 вопросов из 170 решенных удивительно быстро
# Пользователь Петровский Дмитрий (id: 82) решил 24 вопросов из 164 решенных удивительно быстро
# Пользователь Симанович Роман (id: 115) решил 45 вопросов из 146 решенных удивительно быстро
# Пользователь Мурыгин Владислав (id: 118) решил 59 вопросов из 115 решенных удивительно быстро
# Пользователь Лобазов Илья (id: 119) решил 43 вопросов из 133 решенных удивительно быстро
# Пользователь Горошко Матвей (id: 120) решил 53 вопросов из 151 решенных удивительно быстро
# Пользователь Лещук Максим (id: 121) решил 54 вопросов из 83 решенных удивительно быстро
# Пользователь Каминский Никита (id: 122) решил 13 вопросов из 55 решенных удивительно быстро
# Пользователь Колячко Максим (id: 123) решил 38 вопросов из 52 решенных удивительно быстро
# Пользователь Скорябкин Артем (id: 124) решил 10 вопросов из 69 решенных удивительно быстро
# Пользователь Жарский Денис (id: 125) решил 36 вопросов из 66 решенных удивительно быстро
# Пользователь Дмитриев Владислав (id: 126) решил 11 вопросов из 56 решенных удивительно быстро
# Пользователь Протосовицкая Софья (id: 127) решил 28 вопросов из 73 решенных удивительно быстро
# Пользователь Рында Артем (id: 128) решил 23 вопросов из 62 решенных удивительно быстро
# Пользователь Бирич Павел (id: 129) решил 36 вопросов из 60 решенных удивительно быстро
# Пользователь Вдовенко Кирилл (id: 130) решил 37 вопросов из 78 решенных удивительно быстро
# Пользователь Капицын Александр Андреевич (id: 131) решил 58 вопросов из 68 решенных удивительно быстро
# Пользователь Дудич Николай (id: 132) решил 44 вопросов из 69 решенных удивительно быстро
# Пользователь Клебча Антон (id: 133) решил 26 вопросов из 67 решенных удивительно быстро
# Пользователь Соколов Алексей (id: 134) решил 36 вопросов из 64 решенных удивительно быстро
# Пользователь Яблонский Антон (id: 135) решил 39 вопросов из 54 решенных удивительно быстро
# Пользователь Петушок Илья (id: 136) решил 29 вопросов из 52 решенных удивительно быстро
# Пользователь Высоцкий Егор (id: 137) решил 16 вопросов из 38 решенных удивительно быстро
# Пользователь Сильванович Иван (id: 138) решил 26 вопросов из 68 решенных удивительно быстро
# Пользователь Котелков Антон (id: 139) решил 24 вопросов из 84 решенных удивительно быстро
# Пользователь Юдин Георгий (id: 140) решил 42 вопросов из 64 решенных удивительно быстро
# Пользователь Касьян Алексей (id: 141) решил 47 вопросов из 67 решенных удивительно быстро
# Пользователь Хомбак Андрей (id: 142) решил 15 вопросов из 73 решенных удивительно быстро
# Пользователь Рубец Владимир (id: 143) решил 29 вопросов из 69 решенных удивительно быстро
# Пользователь Михалюк Денис (id: 146) решил 58 вопросов из 111 решенных удивительно быстро
# Пользователь Булай Алеся (id: 151) решил 38 вопросов из 84 решенных удивительно быстро
# Пользователь Булгаков Роман (id: 155) решил 38 вопросов из 55 решенных удивительно быстро
# Пользователь anakilivo (id: 165) решил 49 вопросов из 190 решенных удивительно быстро
# Пользователь Мартынюк Роман (id: 166) решил 40 вопросов из 102 решенных удивительно быстро
# Пользователь Базыльчик Александр (id: 167) решил 62 вопросов из 157 решенных удивительно быстро
# Пользователь Вашкелевич Павел (id: 168) решил 67 вопросов из 128 решенных удивительно быстро
# Пользователь Косач Вадим (id: 169) решил 50 вопросов из 107 решенных удивительно быстро
# Пользователь Драчёв Ярослав (id: 170) решил 43 вопросов из 115 решенных удивительно быстро
# Пользователь Трегубов Иван (id: 171) решил 47 вопросов из 74 решенных удивительно быстро
# Пользователь Горбач Максим (id: 172) решил 47 вопросов из 122 решенных удивительно быстро
# Пользователь Гурский Евгений (id: 173) решил 58 вопросов из 121 решенных удивительно быстро
# Пользователь Козляк Тимофей (id: 174) решил 56 вопросов из 131 решенных удивительно быстро
# Пользователь Демещик Максим (id: 175) решил 28 вопросов из 142 решенных удивительно быстро
# Пользователь Мицкевич Станислав (id: 176) решил 6 вопросов из 13 решенных удивительно быстро
# Пользователь Ременчик Евгений (id: 178) решил 47 вопросов из 100 решенных удивительно быстро
# Пользователь Кореневский Никита (id: 179) решил 39 вопросов из 70 решенных удивительно быстро
# Пользователь Максим Демидович (id: 180) решил 16 вопросов из 41 решенных удивительно быстро
# Пользователь Belogolovay_NV_18 (id: 182) решил 3 вопросов из 3 решенных удивительно быстро
# Пользователь Sashka (id: 184) решил 6 вопросов из 12 решенных удивительно быстро
# Пользователь Александр Маскевич (id: 185) решил 20 вопросов из 44 решенных удивительно быстро
# Пользователь Asiya (id: 186) решил 4 вопросов из 13 решенных удивительно быстро
# Пользователь kosmos (id: 187) решил 3 вопросов из 4 решенных удивительно быстро
# Пользователь Half.Teacher (id: 188) решил 9 вопросов из 29 решенных удивительно быстро
# Пользователь testGutsko (id: 190) решил 2 вопросов из 2 решенных удивительно быстро

# %%
#КАКОЙ ПРОЦЕНТ ПРАВИЛЬНЫХ ОТВЕТОВ ОТ ОБЩЕГО ЧИСЛА У КАЖДОГО ПОЛЬЗОВАТЕЛЯ

import json

with open('E:/course work/CTF MF.2022-02-10/db/users.json') as file:
    f = file.read()
    users = json.loads(f)

with open('E:/course work/CTF MF.2022-02-10/db/submissions.json') as file:
    f = file.read()
    submissions = json.loads(f)

for user in users['results']:
    all_answers = 0
    correct_answers = 0
    for data in submissions['results']:
        if user['id'] == data['user_id']:
            all_answers += 1
            if data['type'] == "correct":
                correct_answers += 1
    if all_answers != 0:
        percent = round(correct_answers/all_answers * 100, 2)
        print(f"У {user['name']} (id: {user['id']}) {correct_answers} правильных ответов из {all_answers} попыток решения: {percent}%")
# Out:
# У kadan (id: 5) 5 правильных ответов из 6 попыток решения: 83.33%
# У Каревский Арсентий (id: 13) 123 правильных ответов из 275 попыток решения: 44.73%
# У Куликов Дмитрий (id: 14) 148 правильных ответов из 294 попыток решения: 50.34%
# У Лелевич Алексей (id: 15) 160 правильных ответов из 383 попыток решения: 41.78%
# У Alice (id: 16) 177 правильных ответов из 177 попыток решения: 100.0%
# У Новиков Родион (id: 29) 129 правильных ответов из 321 попыток решения: 40.19%
# У Клеменя Алеся (id: 31) 105 правильных ответов из 261 попыток решения: 40.23%
# У Санько Дмитрий (id: 32) 148 правильных ответов из 360 попыток решения: 41.11%
# У Скоробогатов Иван (id: 34) 116 правильных ответов из 250 попыток решения: 46.4%
# У Беззубик Григорий (id: 73) 170 правильных ответов из 445 попыток решения: 38.2%
# У Петровский Дмитрий (id: 82) 164 правильных ответов из 461 попыток решения: 35.57%
# У Симанович Роман (id: 115) 146 правильных ответов из 407 попыток решения: 35.87%
# У Мурыгин Владислав (id: 118) 115 правильных ответов из 225 попыток решения: 51.11%
# У Лобазов Илья (id: 119) 133 правильных ответов из 451 попыток решения: 29.49%
# У Горошко Матвей (id: 120) 151 правильных ответов из 454 попыток решения: 33.26%
# У Лещук Максим (id: 121) 83 правильных ответов из 116 попыток решения: 71.55%
# У Каминский Никита (id: 122) 55 правильных ответов из 104 попыток решения: 52.88%
# У Колячко Максим (id: 123) 52 правильных ответов из 62 попыток решения: 83.87%
# У Скорябкин Артем (id: 124) 69 правильных ответов из 76 попыток решения: 90.79%
# У Жарский Денис (id: 125) 66 правильных ответов из 114 попыток решения: 57.89%
# У Дмитриев Владислав (id: 126) 56 правильных ответов из 84 попыток решения: 66.67%
# У Протосовицкая Софья (id: 127) 73 правильных ответов из 148 попыток решения: 49.32%
# У Рында Артем (id: 128) 62 правильных ответов из 193 попыток решения: 32.12%
# У Бирич Павел (id: 129) 60 правильных ответов из 135 попыток решения: 44.44%
# У Вдовенко Кирилл (id: 130) 78 правильных ответов из 176 попыток решения: 44.32%
# У Капицын Александр Андреевич (id: 131) 68 правильных ответов из 100 попыток решения: 68.0%
# У Дудич Николай (id: 132) 69 правильных ответов из 107 попыток решения: 64.49%
# У Клебча Антон (id: 133) 67 правильных ответов из 216 попыток решения: 31.02%
# У Соколов Алексей (id: 134) 64 правильных ответов из 128 попыток решения: 50.0%
# У Яблонский Антон (id: 135) 54 правильных ответов из 70 попыток решения: 77.14%
# У Петушок Илья (id: 136) 52 правильных ответов из 177 попыток решения: 29.38%
# У Высоцкий Егор (id: 137) 38 правильных ответов из 93 попыток решения: 40.86%
# У Сильванович Иван (id: 138) 68 правильных ответов из 100 попыток решения: 68.0%
# У Котелков Антон (id: 139) 84 правильных ответов из 175 попыток решения: 48.0%
# У Юдин Георгий (id: 140) 64 правильных ответов из 81 попыток решения: 79.01%
# У Касьян Алексей (id: 141) 67 правильных ответов из 115 попыток решения: 58.26%
# У Хомбак Андрей (id: 142) 73 правильных ответов из 148 попыток решения: 49.32%
# У Рубец Владимир (id: 143) 69 правильных ответов из 93 попыток решения: 74.19%
# У Михалюк Денис (id: 146) 111 правильных ответов из 475 попыток решения: 23.37%
# У Булай Алеся (id: 151) 84 правильных ответов из 156 попыток решения: 53.85%
# У Булгаков Роман (id: 155) 55 правильных ответов из 92 попыток решения: 59.78%
# У anakilivo (id: 165) 190 правильных ответов из 190 попыток решения: 100.0%
# У Мартынюк Роман (id: 166) 102 правильных ответов из 496 попыток решения: 20.56%
# У Базыльчик Александр (id: 167) 157 правильных ответов из 433 попыток решения: 36.26%
# У Вашкелевич Павел (id: 168) 128 правильных ответов из 255 попыток решения: 50.2%
# У Косач Вадим (id: 169) 107 правильных ответов из 231 попыток решения: 46.32%
# У Драчёв Ярослав (id: 170) 115 правильных ответов из 537 попыток решения: 21.42%
# У Трегубов Иван (id: 171) 74 правильных ответов из 243 попыток решения: 30.45%
# У Горбач Максим (id: 172) 122 правильных ответов из 277 попыток решения: 44.04%
# У Гурский Евгений (id: 173) 121 правильных ответов из 398 попыток решения: 30.4%
# У Козляк Тимофей (id: 174) 131 правильных ответов из 197 попыток решения: 66.5%
# У Демещик Максим (id: 175) 142 правильных ответов из 583 попыток решения: 24.36%
# У Мицкевич Станислав (id: 176) 13 правильных ответов из 107 попыток решения: 12.15%
# У Ременчик Евгений (id: 178) 100 правильных ответов из 167 попыток решения: 59.88%
# У Кореневский Никита (id: 179) 70 правильных ответов из 112 попыток решения: 62.5%
# У Максим Демидович (id: 180) 41 правильных ответов из 75 попыток решения: 54.67%
# У Belogolovay_NV_18 (id: 182) 3 правильных ответов из 7 попыток решения: 42.86%
# У Sashka (id: 184) 12 правильных ответов из 21 попыток решения: 57.14%
# У Александр Маскевич (id: 185) 44 правильных ответов из 131 попыток решения: 33.59%
# У Asiya (id: 186) 13 правильных ответов из 32 попыток решения: 40.62%
# У kosmos (id: 187) 4 правильных ответов из 4 попыток решения: 100.0%
# У Half.Teacher (id: 188) 29 правильных ответов из 136 попыток решения: 21.32%
# У testGutsko (id: 190) 2 правильных ответов из 2 попыток решения: 100.0%

# %%
#ПРОЦЕНТ ПРАВИЛЬНЫХ ОТВЕТОВ В КАЖДОЙ КАТЕГОРИИ

import json

with open('E:/course work/CTF MF.2022-02-10/db/submissions.json') as file:
    f = file.read()
    submissions = json.loads(f)

with open('E:/course work/CTF MF.2022-02-10/db/challenges.json') as file:
    f = file.read()
    challenges = json.loads(f)

allanswers = dict()
correctanswers = dict()
for data in submissions['results']:
    for task in challenges['results']:
        if data['challenge_id'] == task['id']:
            if task['category'] in allanswers.keys():
                allanswers[task['category']] += 1
            else:
                allanswers[task['category']] = 1

            if data['type'] == "correct":
                if task['category'] in correctanswers.keys():
                    correctanswers[task['category']] += 1
                else:
                    correctanswers[task['category']] = 1

for key, value in allanswers.items():
    percent = round(correctanswers[key] / value * 100, 2)
    print(f"Процент решений задач в категории \"{key}\": {percent}%. Всего ответов: {value}, правильных: {correctanswers[key]}")
# Out:
# Процент решений задач в категории "CTF 00 Welcome": 45.48%. Всего ответов: 409, правильных: 186
# Процент решений задач в категории "CTF 02 Кодировки": 45.14%. Всего ответов: 3035, правильных: 1370
# Процент решений задач в категории "CTF 04 Симметричное шифрование": 38.42%. Всего ответов: 1809, правильных: 695
# Процент решений задач в категории "CTF 06 Анализ кода": 34.55%. Всего ответов: 330, правильных: 114
# Процент решений задач в категории "CTF 07 Форензика": 36.88%. Всего ответов: 423, правильных: 156
# Процент решений задач в категории "CTF 08 Стеганография": 27.71%. Всего ответов: 83, правильных: 23
# Процент решений задач в категории "CTF 01 Модульная арифметика": 44.59%. Всего ответов: 2189, правильных: 976
# Процент решений задач в категории "CTF 05 Асимметричное шифрование": 54.75%. Всего ответов: 727, правильных: 398
# Процент решений задач в категории "CTF 03 Буквенные шифры": 41.48%. Всего ответов: 2230, правильных: 925
# Процент решений задач в категории "CTF 09 OSINT": 24.18%. Всего ответов: 521, правильных: 126
# Процент решений задач в категории "CTF 19. Разное": 37.07%. Всего ответов: 963, правильных: 357
# Процент решений задач в категории "CS": 78.32%. Всего ответов: 143, правильных: 112
# Процент решений задач в категории "CTF 10 PPC. Professional Programming and Coding": 12.96%. Всего ответов: 54, правильных: 7
# Процент решений задач в категории "CTF 11. Web & Network": 27.27%. Всего ответов: 22, правильных: 6

# %%
#ГРАФИК КОЛИЧЕСТВА ОТВЕТОВ В ДНИ НЕДЕЛИ

import calendar
import json
from datetime import datetime
import matplotlib.pyplot as plot

def WeekDayRus (text):
    if text == "Monday":
        return "Понедельник"
    if text == "Tuesday":
        return "Вторник"
    if text == "Wednesday":
        return "Среда"
    if text == "Thursday":
        return "Четверг"
    if text == "Friday":
        return "Пятница"
    if text == "Saturday":
        return "Суббота"
    if text == "Sunday":
        return "Воскресенье"

with open('E:/course work/CTF MF.2022-02-10/db/submissions.json') as file:
    f = file.read()
    submissions = json.loads(f)

days = dict()
for data in submissions['results']:
    text_date = datetime.fromisoformat((data['date'])).strftime('%Y-%m-%d')
    dayOfWeek = datetime.strptime(text_date, '%Y-%m-%d').weekday()
    dayRus = WeekDayRus(calendar.day_name[dayOfWeek])
    if dayRus in days.keys():
        days[dayRus] += 1
    else:
        days[dayRus] = 1

plot.subplots_adjust(bottom = 0.2)
plot.xticks(rotation=45)
plot.title("Количество ответов по дням недели")
plot.ylabel('Количество ответов')
plot.bar(days.keys(), days.values())
plot.savefig('E:/course work/Отчёт по дням недели.png')
plot.show()

# %%
#ГРАФИК КОЛИЧЕСТВА ОТВЕТОВ ПО ЧАСАМ

import json
from datetime import datetime
import matplotlib.pyplot as plot

with open('E:/course work/CTF MF.2022-02-10/db/submissions.json') as file:
    f = file.read()
    submissions = json.loads(f)

times = dict()
for data in submissions['results']:
    text_time = datetime.fromisoformat((data['date'])).strftime('%H')
    time = int(text_time)

    if time in times.keys():
        times[time] += 1
    else:
        times[time] = 1

i = 0
while i < 24:
    if i not in times.keys():
        times[i] = 0
    i += 1

sorted_times = dict()
list_keys = list(times.keys())
list_keys.sort()
for i in list_keys:
    sorted_times[i] = times[i]

hours = []
values = []
for key, value in sorted_times.items():
    hour = f"{key}:00"
    hours.append(hour)
    values.append(value)

plot.figure(figsize=(8,6))
plot.xticks(rotation=45)
plot.title("Количество ответов по времени дня")
plot.ylabel('Количество ответов')
plot.bar(hours, values)
plot.savefig('E:/course work/Отчёт по времени дня.png')
plot.show()

# %%
#ГРАФИК КОЛИЧЕСТВА ОТВЕТОВ В КАЖДЫЙ МЕСЯЦ

import json
from datetime import datetime
import matplotlib.pyplot as plot

with open('E:/course work/CTF MF.2022-02-10/db/submissions.json') as file:
    f = file.read()
    submissions = json.loads(f)

months = dict()
for data in submissions['results']:
    text_month = datetime.fromisoformat((data['date'])).strftime('%Y-%m')
    if text_month in months.keys():
        months[text_month] += 1
    else:
        months[text_month] = 1

plot.plot(months.keys(), months.values(), color = 'b', linewidth = 2)
plot.title("Количество ответов по месяцам")
plot.ylabel('Количество ответов')
plot.minorticks_on()
plot.grid(which='major', color = 'k', linewidth = 1)
plot.grid(which='minor', color = 'k', linestyle = ':')
plot.savefig('E:/course work/Отчёт по месяцам (кол-во ответов).png')
plot.show()

# %%
#ГРАФИК, СКОЛЬКО ЗАДАЧ РЕШИЛА КАЖДАЯ ГРУППА

import json
import matplotlib.pyplot as plot

with open('E:/course work/CTF MF.2022-02-10/db/users.json') as file:
    f = file.read()
    users = json.loads(f)

with open('E:/course work/CTF MF.2022-02-10/db/submissions.json') as file:
    f = file.read()
    submissions = json.loads(f)

groups = dict()
for x in users['results']:
    for y in submissions['results']:
        if x['id'] == y['user_id'] and y['type'] == 'correct':
            if x['affiliation'] in groups.keys():
                groups[x['affiliation']] += 1
            else:
                groups[x['affiliation']] = 1

groups["Не указана"] = groups.pop(None)
plot.title("Количество правильных ответов по группам")
plot.ylabel('Количество ответов')
plot.bar(groups.keys(), groups.values(), color = 'g')
plot.savefig('E:/course work/Отчёт по группам (кол-во правильных ответов).png')
plot.show()

# %%
#ПРОЦЕНТНОЕ СООТНОШЕНИЕ ИСПОЛЬЗОВАНИЯ ПЛАТФОРМЫ ПО ГРУППАМ

import json
import matplotlib.pyplot as plot

with open('E:/course work/CTF MF.2022-02-10/db/users.json') as file:
    f = file.read()
    users = json.loads(f)

with open('E:/course work/CTF MF.2022-02-10/db/submissions.json') as file:
    f = file.read()
    submissions = json.loads(f)

groups = dict()
all_answers = 0
for x in users['results']:
    for y in submissions['results']:
        if x['id'] == y['user_id']:
            all_answers += 1
            if x['affiliation'] in groups.keys():
                groups[x['affiliation']] += 1
            else:
                groups[x['affiliation']] = 1

groups["Не указана"] = groups.pop(None)

for key, value in groups.items():
    groups[key] = round(value / all_answers * 100,2)

plot.figure(figsize=(7,5))
plot.pie(groups.values(), labels=groups.keys(), autopct='%.2f%%')
plot.axis('equal')
plot.title(f"Использование платформы по группам \n Всего попыток решения: {all_answers}")
plot.savefig('E:/course work/Использование платформы по группам.png')
plot.show()

# %%
#КОЛ-ВО ОТВЕТОВ И КОЛ-ВО ПРАВИЛЬНЫХ ПО КАТЕГОРИЯМ

import json
import matplotlib.pyplot as plot
import pandas as pd
import numpy as np

with open('E:/course work/CTF MF.2022-02-10/db/submissions.json') as file:
    f = file.read()
    submissions = json.loads(f)

with open('E:/course work/CTF MF.2022-02-10/db/challenges.json') as file:
    f = file.read()
    challenges = json.loads(f)


answers = dict()
for data in submissions['results']:
    for task in challenges['results']:
        if data['challenge_id'] == task['id']:
            if task['category'] in answers.keys() and data['type'] == "correct":
                answers[task['category']]['all answers'] += 1
                answers[task['category']]['correct answers'] +=1
            elif task['category'] in answers.keys() and data['type'] != "correct":
                answers[task['category']]['all answers'] += 1
            elif task['category'] not in answers.keys() and data['type'] == "correct":
                answers[task['category']] = {'all answers': 1, 'correct answers': 1}
            else:
                answers[task['category']] = {'all answers': 1, 'correct answers': 0}

sorted_answers = dict()
list_keys = list(answers.keys())
list_keys.sort()
for i in list_keys:
    sorted_answers[i] = answers[i]

index = np.arange(len(sorted_answers))
df = pd.DataFrame(sorted_answers.values())
df.plot(kind='bar', figsize = (8,8.5))
plot.title('Количество всех и правильных ответов по категориям')
plot.subplots_adjust(bottom = 0.5, top = 0.9)
plot.xticks(rotation=90)
plot.xticks(index, sorted_answers.keys())
plot.savefig('E:/course work/Количество ответов по категориям.png')
plot.show()

# %%
#ТАБЛИЦА ДЛЯ ГРУППЫ: КОЛ-ВО РЕШЕННЫХ ЗАДАЧ В КАТЕГОРИИ
# !pip install prettytable

import json
from prettytable import PrettyTable

def rows(key, value):
    str = [key]
    for i in value:
        str.append(value[i])
    return str

def fields(lis):
    str = ["Name"]
    for i in lis:
        str.append(i)
    return str

with open('E:/course work/CTF MF.2022-02-10/db/submissions.json') as file:
    f = file.read()
    submissions = json.loads(f)

with open('E:/course work/CTF MF.2022-02-10/db/users.json') as file:
    f = file.read()
    users = json.loads(f)

with open('E:/course work/CTF MF.2022-02-10/db/challenges.json') as file:
    f = file.read()
    challenges = json.loads(f)

group = input("Введите группу: ")
count = 0
for data in users['results']:
    if data['affiliation'] == group:
        count += 1
if count == 0:
    print("Такой группы нет в системе. Проверьте введенные данные!")
    quit()

answers = dict()
categories = list()

for sub in submissions['results']:
    for user in users['results']:
        if sub['type'] == "correct" and sub['user_id'] == user['id'] and user['affiliation'] == group:
            userName = user['name']
            for chall in challenges['results']:
                if sub['challenge_id'] == chall['id']:
                    if userName in answers.keys() and chall['category'] in answers[userName].keys():
                        answers[userName][chall['category']] +=1
                    elif userName in answers.keys() and chall['category'] not in answers[userName].keys():
                        answers[userName][chall['category']] = 1
                    elif userName not in answers.keys():
                        answers[userName] = {f"{chall['category']}": 1}

                    if chall['category'] not in categories:
                        categories.append(chall['category'])


sorted_answers = dict()
list_keys = categories
list_keys.sort()
for key, value in answers.items():
    for i in list_keys:
        if i in answers[key].keys():
            if key in sorted_answers.keys():
                sorted_answers[key][i] = value[i]
            else:
                sorted_answers[key] = {f"{i}": value[i]}
        else:
            sorted_answers[key][i] = 0

mytable = PrettyTable()
mytable.field_names = [x for x in fields(list_keys)]
for key, value in sorted_answers.items():
    mytable.add_row([x for x in rows(key, value)])

with open(f'E:/course work/Отчёт для группы {group}.txt', 'w') as f:
    table = mytable.get_string()
    f.write(f"Группа: {group}\n")
    f.write(table)
    f.write('\n')
print("Таблица успешно создана! Файл сохранен на ваш компьютер")
# Out:
# Requirement already satisfied: prettytable in e:\anaconda\lib\site-packages (3.3.0)
# Requirement already satisfied: wcwidth in e:\anaconda\lib\site-packages (from prettytable) (0.2.5)
# Введите группу: КБ-191
# Таблица успешно создана! Файл сохранен на ваш компьютер

# %%
#ОТЧЕТ (ТАБЛИЦА) ДЛЯ ГРУППЫ НА СЕМЕСТР

# !pip install prettytable

import json
from prettytable import PrettyTable
from datetime import datetime

def rows(key, value):
    str = [key]
    for i in value:
        str.append(value[i])
    return str

def fields(lis):
    str = ["Name"]
    for i in lis:
        str.append(i)
    return str

with open('E:/course work/CTF MF.2022-02-10/db/submissions.json') as file:
    f = file.read()
    submissions = json.loads(f)

with open('E:/course work/CTF MF.2022-02-10/db/users.json') as file:
    f = file.read()
    users = json.loads(f)

with open('E:/course work/CTF MF.2022-02-10/db/challenges.json') as file:
    f = file.read()
    challenges = json.loads(f)

group = input("Введите группу: ")
count = 0
for data in users['results']:
    if data['affiliation'] == group:
        count += 1
if count == 0:
    print("Такой группы нет в системе. Проверьте введенные данные!")
    quit()

answers = dict()
categories = list()

for sub in submissions['results']:
    for user in users['results']:
        text_date = datetime.fromisoformat((sub['date'])).strftime('%Y-%m-%d')
        date = datetime.strptime(text_date, '%Y-%m-%d')
        if sub['type'] == "correct" and sub['user_id'] == user['id'] and user['affiliation'] == group:
            if date > datetime(2021, 9, 1) and date < datetime(2022, 1, 1):
                userName = user['name']
                for chall in challenges['results']:
                    if sub['challenge_id'] == chall['id']:
                        if userName in answers.keys() and chall['category'] in answers[userName].keys():
                            answers[userName][chall['category']] +=1
                        elif userName in answers.keys() and chall['category'] not in answers[userName].keys():
                            answers[userName][chall['category']] = 1
                        elif userName not in answers.keys():
                            answers[userName] = {f"{chall['category']}": 1}

                        if chall['category'] not in categories:
                            categories.append(chall['category'])


sorted_answers = dict()
list_keys = categories
list_keys.sort()
for key, value in answers.items():
    for i in list_keys:
        if i in answers[key].keys():
            if key in sorted_answers.keys():
                sorted_answers[key][i] = value[i]
            else:
                sorted_answers[key] = {f"{i}": value[i]}
        else:
            sorted_answers[key][i] = 0

mytable = PrettyTable()
mytable.field_names = [x for x in fields(list_keys)]
for key, value in sorted_answers.items():
    mytable.add_row([x for x in rows(key, value)])

with open(f'E:/course work/Отчёт для группы {group} за семестр.txt', 'w') as f:
    table = mytable.get_string()
    f.write(f"Группа: {group}\n")
    f.write(f"Отчёт по количеству решенных задач в каждой категории за период 09.2021 - 01.2022\n")
    f.write(table)
    f.write('\n')
print("Таблица успешно создана! Файл сохранен на ваш компьютер")
# Out:
# Requirement already satisfied: prettytable in e:\anaconda\lib\site-packages (3.3.0)
# Requirement already satisfied: wcwidth in e:\anaconda\lib\site-packages (from prettytable) (0.2.5)
# Введите группу: ви
# Такой группы нет в системе. Проверьте введенные данные!
# Таблица успешно создана! Файл сохранен на ваш компьютер

# %%
#ОТЧЕТ (ТАБЛИЦА) ДЛЯ ГРУППЫ: СКОЛЬКО ПРОЦЕНТОВ ЗАДАЧ ИЗ КАЖДОЙ КАТЕГОРИИ РЕШИЛ СТУДЕНТ

# !pip install prettytable

import json
from prettytable import PrettyTable
from datetime import datetime

def rows(key, value):
    str = [key]
    for i in value:
        str.append(value[i])
    return str

def fields(lis):
    str = ["Name"]
    for i in lis:
        str.append(i)
    return str

with open('E:/course work/CTF MF.2022-02-10/db/submissions.json') as file:
    f = file.read()
    submissions = json.loads(f)

with open('E:/course work/CTF MF.2022-02-10/db/users.json') as file:
    f = file.read()
    users = json.loads(f)

with open('E:/course work/CTF MF.2022-02-10/db/challenges.json') as file:
    f = file.read()
    challenges = json.loads(f)

group = input("Введите группу: ")
count = 0
for data in users['results']:
    if data['affiliation'] == group:
        count += 1
if count == 0:
    print("Такой группы нет в системе. Проверьте введенные данные!")
    quit()

cat = dict()
for challenge in challenges['results']:
    if challenge['category'] in cat.keys():
        cat[challenge['category']] +=1
    else:
        cat[challenge['category']] = 1

answers = dict()
categories = list()

for sub in submissions['results']:
    for user in users['results']:
        if sub['type'] == "correct" and sub['user_id'] == user['id'] and user['affiliation'] == group:
            userName = user['name']
            for chall in challenges['results']:
                if sub['challenge_id'] == chall['id']:
                    if userName in answers.keys() and chall['category'] in answers[userName].keys():
                        answers[userName][chall['category']] +=1
                    elif userName in answers.keys() and chall['category'] not in answers[userName].keys():
                        answers[userName][chall['category']] = 1
                    elif userName not in answers.keys():
                        answers[userName] = {f"{chall['category']}": 1}

                    if chall['category'] not in categories:
                        categories.append(chall['category'])


sorted_answers = dict()
list_keys = categories
list_keys.sort()
for key, value in answers.items():
    for i in list_keys:
        if i in answers[key].keys():
            if key in sorted_answers.keys():
                sorted_answers[key][i] = f"{round(value[i] / cat[i] * 100, 2)} %"
            else:
                sorted_answers[key] = {f"{i}": f"{round(value[i] / cat[i] * 100, 2)} %"}
        else:
            sorted_answers[key][i] = 0

mytable = PrettyTable()
mytable.field_names = [x for x in fields(list_keys)]
for key, value in sorted_answers.items():
    mytable.add_row([x for x in rows(key, value)])
print(mytable)

with open(f'E:/course work/Отчёт для группы {group} в процентах.txt', 'w') as f:
    table = mytable.get_string()
    f.write(f"Группа: {group}\n")
    f.write(table)
    f.write('\n')
# Out:
# Requirement already satisfied: prettytable in e:\anaconda\lib\site-packages (3.3.0)
# Requirement already satisfied: wcwidth in e:\anaconda\lib\site-packages (from prettytable) (0.2.5)
# Введите группу: КБ-191
# +-----------------------------+----------------+-----------------------------+------------------+------------------------+--------------------------------+---------------------------------+--------------------+------------------+--------------+-------------------------------------------------+-----------------------+----------------+
# |             Name            | CTF 00 Welcome | CTF 01 Модульная арифметика | CTF 02 Кодировки | CTF 03 Буквенные шифры | CTF 04 Симметричное шифрование | CTF 05 Асимметричное шифрование | CTF 06 Анализ кода | CTF 07 Форензика | CTF 09 OSINT | CTF 10 PPC. Professional Programming and Coding | CTF 11. Web & Network | CTF 19. Разное |
# +-----------------------------+----------------+-----------------------------+------------------+------------------------+--------------------------------+---------------------------------+--------------------+------------------+--------------+-------------------------------------------------+-----------------------+----------------+
# | Капицын Александр Андреевич |     75.0 %     |            95.0 %           |     81.25 %      |         44.0 %         |            26.47 %             |                0                |         0          |        0         |      0       |                        0                        |           0           |       0        |
# |        Жарский Денис        |     75.0 %     |            95.0 %           |      37.5 %      |         72.0 %         |            26.47 %             |             19.23 %             |         0          |        0         |      0       |                        0                        |           0           |       0        |
# |        Хомбак Андрей        |     75.0 %     |            95.0 %           |     84.38 %      |         52.0 %         |            26.47 %             |                0                |         0          |        0         |      0       |                     13.33 %                     |           0           |       0        |
# |       Соколов Алексей       |     75.0 %     |            95.0 %           |      75.0 %      |         48.0 %         |            17.65 %             |                0                |         0          |        0         |      0       |                        0                        |           0           |       0        |
# |         Рында Артем         |     75.0 %     |            95.0 %           |     68.75 %      |         36.0 %         |            26.47 %             |                0                |         0          |        0         |      0       |                        0                        |           0           |       0        |
# |       Каминский Никита      |     75.0 %     |            85.0 %           |     59.38 %      |         48.0 %         |            11.76 %             |                0                |         0          |        0         |      0       |                        0                        |           0           |       0        |
# |     Протосовицкая Софья     |     75.0 %     |            95.0 %           |     68.75 %      |         72.0 %         |            20.59 %             |             15.38 %             |         0          |        0         |      0       |                        0                        |           0           |       0        |
# |        Котелков Антон       |     75.0 %     |            95.0 %           |     81.25 %      |         60.0 %         |            26.47 %             |                0                |         0          |        0         |   83.33 %    |                        0                        |           0           |    33.33 %     |
# |         Лещук Максим        |     75.0 %     |            95.0 %           |     81.25 %      |         52.0 %         |            26.47 %             |             15.38 %             |      42.86 %       |      10.0 %      |      0       |                        0                        |           0           |     9.52 %     |
# |      Дмитриев Владислав     |     75.0 %     |            75.0 %           |     59.38 %      |         44.0 %         |            23.53 %             |                0                |         0          |        0         |      0       |                        0                        |           0           |       0        |
# |        Рубец Владимир       |     75.0 %     |            95.0 %           |     81.25 %      |         48.0 %         |            26.47 %             |                0                |         0          |        0         |      0       |                        0                        |           0           |       0        |
# |        Касьян Алексей       |     75.0 %     |            95.0 %           |     71.88 %      |         56.0 %         |            23.53 %             |                0                |         0          |        0         |      0       |                        0                        |           0           |       0        |
# |         Булай Алеся         |     75.0 %     |            95.0 %           |     81.25 %      |         60.0 %         |            26.47 %             |             19.23 %             |         0          |      20.0 %      |   16.67 %    |                        0                        |         50.0 %        |     9.52 %     |
# |        Булгаков Роман       |     75.0 %     |            85.0 %           |     56.25 %      |         48.0 %         |            14.71 %             |                0                |         0          |        0         |      0       |                        0                        |           0           |       0        |
# |       Вдовенко Кирилл       |     75.0 %     |            95.0 %           |     81.25 %      |         60.0 %         |            26.47 %             |             15.38 %             |         0          |        0         |   16.67 %    |                        0                        |           0           |     4.76 %     |
# |       Сильванович Иван      |     75.0 %     |            85.0 %           |     81.25 %      |         52.0 %         |            26.47 %             |                0                |         0          |        0         |      0       |                        0                        |           0           |       0        |
# |         Бирич Павел         |     75.0 %     |            75.0 %           |      75.0 %      |         52.0 %         |            14.71 %             |                0                |         0          |        0         |      0       |                        0                        |           0           |       0        |
# |         Клебча Антон        |     75.0 %     |            90.0 %           |     71.88 %      |         56.0 %         |            26.47 %             |                0                |         0          |        0         |      0       |                        0                        |           0           |       0        |
# |        Высоцкий Егор        |     75.0 %     |              0              |     56.25 %      |         56.0 %         |             8.82 %             |                0                |         0          |        0         |      0       |                        0                        |           0           |       0        |
# |        Колячко Максим       |     75.0 %     |            45.0 %           |     59.38 %      |         48.0 %         |            26.47 %             |                0                |         0          |        0         |      0       |                        0                        |           0           |       0        |
# |        Дудич Николай        |     75.0 %     |            95.0 %           |     81.25 %      |         48.0 %         |            26.47 %             |                0                |         0          |        0         |      0       |                        0                        |           0           |       0        |
# |         Юдин Георгий        |     75.0 %     |            95.0 %           |     84.38 %      |         60.0 %         |               0                |                0                |         0          |        0         |      0       |                        0                        |           0           |       0        |
# |         Петушок Илья        |     75.0 %     |              0              |      75.0 %      |         48.0 %         |            26.47 %             |             15.38 %             |         0          |        0         |      0       |                        0                        |           0           |       0        |
# |       Яблонский Антон       |     75.0 %     |            80.0 %           |     68.75 %      |         36.0 %         |            11.76 %             |                0                |         0          |        0         |      0       |                        0                        |           0           |       0        |
# |      Александр Маскевич     |     75.0 %     |            75.0 %           |     28.12 %      |         48.0 %         |               0                |             19.23 %             |         0          |        0         |      0       |                        0                        |           0           |       0        |
# |       Скорябкин Артем       |     75.0 %     |            95.0 %           |     81.25 %      |         48.0 %         |            26.47 %             |                0                |         0          |        0         |      0       |                        0                        |           0           |       0        |
# +-----------------------------+----------------+-----------------------------+------------------+------------------------+--------------------------------+---------------------------------+--------------------+------------------+--------------+-------------------------------------------------+-----------------------+----------------+
